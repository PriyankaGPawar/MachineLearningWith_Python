# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaGPawar/MachineLearningWith_Python/blob/master/Class_Notebooks/Dendogram_Hierachies_of_stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1:** Load the data _(written for you)_

# %%
import pandas as pd

fn = 'https://raw.githubusercontent.com/benjaminwilson/python-hierarchical-clustering-exercises/master/datasets/company-stock-movements-2010-2015-incl.csv'
stocks_df = pd.read_csv(fn, index_col=0)

companies = list(stocks_df.index)
movements = stocks_df.values

# %%
stocks_df.head()
# Out:
#                   2010-01-04  2010-01-05  ...  2013-10-28  2013-10-29
# Apple               0.580000   -0.220005  ...    0.840019  -19.589981
# AIG                -0.640002   -0.650000  ...   -0.400002    0.660000
# Amazon             -2.350006    1.260009  ...   -1.760009    3.740021
# American express    0.109997    0.000000  ...    0.040001    0.540001
# Boeing              0.459999    1.770000  ...    1.130005    0.309998
#
# [5 rows x 963 columns]

# %% [markdown]
# **Step 2:** Make the necessary imports:
#
#  + `normalize` from `sklearn.preprocessing`.
#  + `linkage` and `dendrogram` from `scipy.cluster.hierarchy`.
#  + `matplotlib.pyplot` as `plt`.

# %%
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 3:** Rescale the price movements for each stock by using the `normalize()` function on `movements`.

# %%
normalized_movements = normalize(movements)

# %% [markdown]
# **Step 4:** Apply the `linkage()` function to `normalized_movements`, using `'complete'` linkage, to calculate the hierarchical clustering. Assign the result to `mergings`.

# %%
mergings = linkage(normalized_movements, method='complete')

# %% [markdown]
# **Step 5:** Plot a dendrogram of the hierarchical clustering, using the list `companies` of company names as the `labels`. In addition, specify the `leaf_rotation=90`, and `leaf_font_size=10` keyword arguments as you did in the previous exercise.

# %%
# the first line is written for you - it sets the size of your plot
plt.figure(figsize=(20, 15))

dendrogram(
    mergings,
    labels=companies,
    leaf_rotation=90.,
    leaf_font_size=10
)
plt.show()
